# %%
# Import dependencie
import pandas as pd
import numpy as np
from citipy import citipy
import json 
import requests
import timeit
from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=531bc4ee40dbf46dc6219b87751e075c

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | pombas
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | sur
# Processing Record 5 of Set 1 | agva
# City not found. Skipping...
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | gollere
# City not found. Skipping...
# Processing Record 9 of Set 1 | tuatapere
# Processing Record 10 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | roald
# Processing Record 13 of Set 1 | maceio
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | kushima
# Processing Record 16 of Set 1 | san policarpo
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | tabas
# Processing Record 19 of Set 1 | morant bay
# Processing Record 20 of Set 1 | lorengau
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | aripuana
# Processing Record 23 of Set 1 | torbay
# Processing Record 24 of Set 1 | ormara
# Processing Record 25 of Set 1 | cherskiy
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | haljala
# Processing Record 28 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | kahului
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | livingstone
# Processing Record 34 of Set 1 | plaridel
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | thompson
# Processing Record 37 of Set 1 | dalhousie
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | san patricio
# Processing Record 43 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 1 | shimoda
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | severnyy-kospashskiy
# Processing Record 48 of Set 1 | bambous virieux
# Processing Record 49 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | padang
# Processing Record 3 of Set 2 | turtkul
# City not found. Skipping...
# Processing Record 4 of Set 2 | drumnadrochit
# Processing Record 5 of Set 2 | jawhar
# Processing Record 6 of Set 2 | victoria
# Processing Record 7 of Set 2 | juneau
# Processing Record 8 of Set 2 | angoche
# Processing Record 9 of Set 2 | catia la mar
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | coahuayana
# Processing Record 12 of Set 2 | vardo
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | saint george
# Processing Record 15 of Set 2 | margate
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | naze
# Processing Record 18 of Set 2 | raudeberg
# Processing Record 19 of Set 2 | husavik
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | nanortalik
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | neon karlovasion
# Processing Record 24 of Set 2 | ippy
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | ocampo
# Processing Record 27 of Set 2 | spirovo
# Processing Record 28 of Set 2 | ostrovnoy
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | hervey bay
# Processing Record 34 of Set 2 | pevek
# Processing Record 35 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | gedo
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | barra patuca
# Processing Record 42 of Set 2 | puri
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | ambositra
# Processing Record 45 of Set 2 | torres
# Processing Record 46 of Set 2 | longyearbyen
# Processing Record 47 of Set 2 | sinnamary
# Processing Record 48 of Set 2 | lagoa
# Processing Record 49 of Set 2 | khor
# Processing Record 50 of Set 2 | marica
# Processing Record 1 of Set 3 | klaksvik
# Processing Record 2 of Set 3 | beloha
# Processing Record 3 of Set 3 | krasnouralsk
# Processing Record 4 of Set 3 | palmer
# Processing Record 5 of Set 3 | turukhansk
# Processing Record 6 of Set 3 | westport
# Processing Record 7 of Set 3 | sorland
# Processing Record 8 of Set 3 | rudnogorsk
# Processing Record 9 of Set 3 | karratha
# Processing Record 10 of Set 3 | tadine
# Processing Record 11 of Set 3 | saint-philippe
# Processing Record 12 of Set 3 | airai
# Processing Record 13 of Set 3 | muros
# Processing Record 14 of Set 3 | mulege
# Processing Record 15 of Set 3 | malanje
# Processing Record 16 of Set 3 | laguna
# Processing Record 17 of Set 3 | calvia
# Processing Record 18 of Set 3 | gamba
# Processing Record 19 of Set 3 | bilma
# Processing Record 20 of Set 3 | kattivakkam
# Processing Record 21 of Set 3 | yumen
# Processing Record 22 of Set 3 | khorixas
# Processing Record 23 of Set 3 | santa isabel do rio negro
# Processing Record 24 of Set 3 | ciurea
# Processing Record 25 of Set 3 | tuskegee
# Processing Record 26 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 3 | mount isa
# Processing Record 28 of Set 3 | nanchong
# Processing Record 29 of Set 3 | albany
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | pechenga
# Processing Record 32 of Set 3 | norman wells
# Processing Record 33 of Set 3 | port blair
# Processing Record 34 of Set 3 | bereda
# Processing Record 35 of Set 3 | touros
# Processing Record 36 of Set 3 | pereslavl-zalesskiy
# Processing Record 37 of Set 3 | okhotsk
# Processing Record 38 of Set 3 | imbituba
# Processing Record 39 of Set 3 | hirara
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | lukulu
# Processing Record 42 of Set 3 | lavras
# Processing Record 43 of Set 3 | luanda
# Processing Record 44 of Set 3 | pulaski
# Processing Record 45 of Set 3 | new norfolk
# Processing Record 46 of Set 3 | ancud
# Processing Record 47 of Set 3 | aldan
# Processing Record 48 of Set 3 | polevskoy
# Processing Record 49 of Set 3 | itarema
# Processing Record 50 of Set 3 | bengkulu
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | revelstoke
# Processing Record 3 of Set 4 | walvis bay
# Processing Record 4 of Set 4 | ojinaga
# Processing Record 5 of Set 4 | buraydah
# Processing Record 6 of Set 4 | yakymivka
# Processing Record 7 of Set 4 | bosaso
# Processing Record 8 of Set 4 | kopavogur
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | mitchell
# Processing Record 11 of Set 4 | vao
# Processing Record 12 of Set 4 | caravelas
# Processing Record 13 of Set 4 | muhos
# Processing Record 14 of Set 4 | avarua
# Processing Record 15 of Set 4 | roebourne
# Processing Record 16 of Set 4 | asau
# Processing Record 17 of Set 4 | dikson
# Processing Record 18 of Set 4 | clyde river
# Processing Record 19 of Set 4 | umba
# Processing Record 20 of Set 4 | hrymayliv
# Processing Record 21 of Set 4 | ilulissat
# Processing Record 22 of Set 4 | bredasdorp
# Processing Record 23 of Set 4 | beringovskiy
# Processing Record 24 of Set 4 | korla
# Processing Record 25 of Set 4 | leningradskiy
# Processing Record 26 of Set 4 | shajapur
# Processing Record 27 of Set 4 | namatanai
# Processing Record 28 of Set 4 | san cristobal
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | elko
# Processing Record 31 of Set 4 | sao felix do xingu
# Processing Record 32 of Set 4 | tuktoyaktuk
# Processing Record 33 of Set 4 | hamilton
# Processing Record 34 of Set 4 | upernavik
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | nizhniy chir
# Processing Record 37 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 4 | okha
# Processing Record 39 of Set 4 | port elizabeth
# Processing Record 40 of Set 4 | chippewa falls
# Processing Record 41 of Set 4 | bridlington
# Processing Record 42 of Set 4 | amapa
# Processing Record 43 of Set 4 | camacha
# Processing Record 44 of Set 4 | abu kamal
# Processing Record 45 of Set 4 | broome
# Processing Record 46 of Set 4 | fuengirola
# Processing Record 47 of Set 4 | tamandare
# Processing Record 48 of Set 4 | asfi
# Processing Record 49 of Set 4 | mackay
# Processing Record 50 of Set 4 | khatanga
# Processing Record 1 of Set 5 | hokitika
# Processing Record 2 of Set 5 | cape town
# Processing Record 3 of Set 5 | cabo san lucas
# Processing Record 4 of Set 5 | manavalakurichi
# Processing Record 5 of Set 5 | muzhi
# Processing Record 6 of Set 5 | leh
# Processing Record 7 of Set 5 | los llanos de aridane
# Processing Record 8 of Set 5 | nieuw amsterdam
# Processing Record 9 of Set 5 | constitucion
# Processing Record 10 of Set 5 | katsuura
# Processing Record 11 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 5 | carutapera
# Processing Record 13 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 5 | bonavista
# Processing Record 15 of Set 5 | sao gabriel da cachoeira
# Processing Record 16 of Set 5 | kousseri
# Processing Record 17 of Set 5 | la palma
# Processing Record 18 of Set 5 | axim
# Processing Record 19 of Set 5 | mahebourg
# Processing Record 20 of Set 5 | teya
# Processing Record 21 of Set 5 | nicoya
# Processing Record 22 of Set 5 | fairbanks
# Processing Record 23 of Set 5 | kuusamo
# Processing Record 24 of Set 5 | ponta do sol
# Processing Record 25 of Set 5 | samokov
# Processing Record 26 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 27 of Set 5 | cabedelo
# Processing Record 28 of Set 5 | chapais
# Processing Record 29 of Set 5 | severo-kurilsk
# Processing Record 30 of Set 5 | siedlce
# Processing Record 31 of Set 5 | ca mau
# Processing Record 32 of Set 5 | kirakira
# Processing Record 33 of Set 5 | kalmunai
# Processing Record 34 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 5 | eureka
# Processing Record 36 of Set 5 | puerto el triunfo
# Processing Record 37 of Set 5 | hudson bay
# Processing Record 38 of Set 5 | ust-kuyga
# Processing Record 39 of Set 5 | oliveira dos brejinhos
# Processing Record 40 of Set 5 | otane
# Processing Record 41 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 5 | hvolsvollur
# Processing Record 43 of Set 5 | shingu
# Processing Record 44 of Set 5 | east london
# Processing Record 45 of Set 5 | luwuk
# Processing Record 46 of Set 5 | cayenne
# Processing Record 47 of Set 5 | ilhabela
# Processing Record 48 of Set 5 | sanmenxia
# Processing Record 49 of Set 5 | zavyalovo
# Processing Record 50 of Set 5 | bayeux
# Processing Record 1 of Set 6 | merrill
# Processing Record 2 of Set 6 | cap-aux-meules
# Processing Record 3 of Set 6 | koslan
# Processing Record 4 of Set 6 | mbini
# Processing Record 5 of Set 6 | lasa
# Processing Record 6 of Set 6 | ha giang
# Processing Record 7 of Set 6 | saldanha
# Processing Record 8 of Set 6 | yulara
# Processing Record 9 of Set 6 | atambua
# Processing Record 10 of Set 6 | adrar
# Processing Record 11 of Set 6 | liaocheng
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | erzin
# Processing Record 14 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 6 | ambon
# Processing Record 16 of Set 6 | mar del plata
# Processing Record 17 of Set 6 | qaanaaq
# Processing Record 18 of Set 6 | chistogorskiy
# Processing Record 19 of Set 6 | denizli
# Processing Record 20 of Set 6 | huayucachi
# Processing Record 21 of Set 6 | ariquemes
# Processing Record 22 of Set 6 | hukuntsi
# Processing Record 23 of Set 6 | waipawa
# Processing Record 24 of Set 6 | pitimbu
# Processing Record 25 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 26 of Set 6 | batemans bay
# Processing Record 27 of Set 6 | sovetskiy
# Processing Record 28 of Set 6 | sao filipe
# Processing Record 29 of Set 6 | saint-joseph
# Processing Record 30 of Set 6 | calama
# Processing Record 31 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 6 | chhatarpur
# Processing Record 33 of Set 6 | puerto carreno
# Processing Record 34 of Set 6 | la esperanza
# Processing Record 35 of Set 6 | santiago
# Processing Record 36 of Set 6 | ardmore
# Processing Record 37 of Set 6 | wazzan
# City not found. Skipping...
# Processing Record 38 of Set 6 | sao joao da barra
# Processing Record 39 of Set 6 | pogradec
# Processing Record 40 of Set 6 | mastung
# Processing Record 41 of Set 6 | honiara
# Processing Record 42 of Set 6 | tonantins
# Processing Record 43 of Set 6 | cairns
# Processing Record 44 of Set 6 | dong hoi
# Processing Record 45 of Set 6 | luderitz
# Processing Record 46 of Set 6 | lerwick
# Processing Record 47 of Set 6 | te anau
# Processing Record 48 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 49 of Set 6 | katobu
# Processing Record 50 of Set 6 | ulaanbaatar
# Processing Record 1 of Set 7 | orotukan
# Processing Record 2 of Set 7 | faanui
# Processing Record 3 of Set 7 | pacific grove
# Processing Record 4 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 7 | kavieng
# Processing Record 6 of Set 7 | xining
# Processing Record 7 of Set 7 | sibu
# Processing Record 8 of Set 7 | hays
# Processing Record 9 of Set 7 | inuvik
# Processing Record 10 of Set 7 | dubrajpur
# Processing Record 11 of Set 7 | kilimatinde
# Processing Record 12 of Set 7 | udankudi
# Processing Record 13 of Set 7 | richmond
# Processing Record 14 of Set 7 | xinqing
# Processing Record 15 of Set 7 | farah
# Processing Record 16 of Set 7 | khasan
# Processing Record 17 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 7 | alofi
# Processing Record 19 of Set 7 | narsaq
# Processing Record 20 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 7 | arrifes
# Processing Record 22 of Set 7 | lamu
# Processing Record 23 of Set 7 | ulcinj
# Processing Record 24 of Set 7 | chaiyaphum
# Processing Record 25 of Set 7 | massakory
# Processing Record 26 of Set 7 | nabire
# Processing Record 27 of Set 7 | byron bay
# Processing Record 28 of Set 7 | tahta
# Processing Record 29 of Set 7 | shabrovskiy
# Processing Record 30 of Set 7 | pozo colorado
# Processing Record 31 of Set 7 | codrington
# Processing Record 32 of Set 7 | meadow lake
# Processing Record 33 of Set 7 | natal
# Processing Record 34 of Set 7 | athabasca
# Processing Record 35 of Set 7 | bilibino
# Processing Record 36 of Set 7 | flinders
# Processing Record 37 of Set 7 | juan lacaze
# Processing Record 38 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 39 of Set 7 | aswan
# Processing Record 40 of Set 7 | sydney
# Processing Record 41 of Set 7 | agirish
# Processing Record 42 of Set 7 | boden
# Processing Record 43 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 44 of Set 7 | chuy
# Processing Record 45 of Set 7 | qaqortoq
# Processing Record 46 of Set 7 | hambantota
# Processing Record 47 of Set 7 | saint-augustin
# Processing Record 48 of Set 7 | kruisfontein
# Processing Record 49 of Set 7 | saint-pierre
# Processing Record 50 of Set 7 | anadyr
# Processing Record 1 of Set 8 | emerald
# Processing Record 2 of Set 8 | vila
# Processing Record 3 of Set 8 | dukat
# Processing Record 4 of Set 8 | beyneu
# Processing Record 5 of Set 8 | mbekenyera
# Processing Record 6 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 8 | tshela
# Processing Record 9 of Set 8 | jhanjharpur
# Processing Record 10 of Set 8 | sawakin
# Processing Record 11 of Set 8 | chiang khong
# Processing Record 12 of Set 8 | kingaroy
# Processing Record 13 of Set 8 | skopin
# Processing Record 14 of Set 8 | khani
# Processing Record 15 of Set 8 | vostok
# Processing Record 16 of Set 8 | moree
# Processing Record 17 of Set 8 | isangel
# Processing Record 18 of Set 8 | port macquarie
# Processing Record 19 of Set 8 | sitka
# Processing Record 20 of Set 8 | marystown
# Processing Record 21 of Set 8 | talnakh
# Processing Record 22 of Set 8 | gull lake
# Processing Record 23 of Set 8 | katherine
# Processing Record 24 of Set 8 | linxia
# Processing Record 25 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 8 | iizuka
# Processing Record 27 of Set 8 | cockburn town
# Processing Record 28 of Set 8 | sagua la grande
# Processing Record 29 of Set 8 | khowst
# Processing Record 30 of Set 8 | souillac
# Processing Record 31 of Set 8 | kapuskasing
# Processing Record 32 of Set 8 | port lincoln
# Processing Record 33 of Set 8 | belaya gora
# Processing Record 34 of Set 8 | hay river
# Processing Record 35 of Set 8 | burgeo
# Processing Record 36 of Set 8 | deming
# Processing Record 37 of Set 8 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 38 of Set 8 | esperance
# Processing Record 39 of Set 8 | fortuna
# Processing Record 40 of Set 8 | arman
# Processing Record 41 of Set 8 | enkhuizen
# Processing Record 42 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 8 | balabac
# Processing Record 44 of Set 8 | nerchinskiy zavod
# Processing Record 45 of Set 8 | ambilobe
# Processing Record 46 of Set 8 | lompoc
# Processing Record 47 of Set 8 | college
# Processing Record 48 of Set 8 | puerto escondido
# Processing Record 49 of Set 8 | langham
# Processing Record 50 of Set 8 | iqaluit
# Processing Record 1 of Set 9 | leshan
# Processing Record 2 of Set 9 | onguday
# Processing Record 3 of Set 9 | portland
# Processing Record 4 of Set 9 | roma
# Processing Record 5 of Set 9 | bambari
# Processing Record 6 of Set 9 | minas
# Processing Record 7 of Set 9 | mahon
# Processing Record 8 of Set 9 | kupiskis
# Processing Record 9 of Set 9 | riyadh
# Processing Record 10 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 9 | port shepstone
# Processing Record 12 of Set 9 | doka
# Processing Record 13 of Set 9 | savalou
# Processing Record 14 of Set 9 | grand haven
# Processing Record 15 of Set 9 | marrakesh
# Processing Record 16 of Set 9 | praia da vitoria
# Processing Record 17 of Set 9 | mount gambier
# Processing Record 18 of Set 9 | komsomolskiy
# Processing Record 19 of Set 9 | hollola
# Processing Record 20 of Set 9 | russell
# Processing Record 21 of Set 9 | enterprise
# Processing Record 22 of Set 9 | vila velha
# Processing Record 23 of Set 9 | gat
# Processing Record 24 of Set 9 | urubicha
# Processing Record 25 of Set 9 | skibbereen
# Processing Record 26 of Set 9 | butka
# Processing Record 27 of Set 9 | bridgeton
# Processing Record 28 of Set 9 | svetlaya
# Processing Record 29 of Set 9 | darhan
# Processing Record 30 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 9 | sirfa
# City not found. Skipping...
# Processing Record 32 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 9 | bairiki
# Processing Record 34 of Set 9 | namibe
# Processing Record 35 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 36 of Set 9 | port hardy
# Processing Record 37 of Set 9 | phek
# Processing Record 38 of Set 9 | aklavik
# Processing Record 39 of Set 9 | kovdor
# Processing Record 40 of Set 9 | atlantic city
# Processing Record 41 of Set 9 | guerrero negro
# Processing Record 42 of Set 9 | jurado
# Processing Record 43 of Set 9 | katha
# City not found. Skipping...
# Processing Record 44 of Set 9 | serebryanyy bor
# Processing Record 45 of Set 9 | san nicolas
# Processing Record 46 of Set 9 | kroderen
# City not found. Skipping...
# Processing Record 47 of Set 9 | sorada
# Processing Record 48 of Set 9 | xiaoweizhai
# Processing Record 49 of Set 9 | edd
# Processing Record 50 of Set 9 | vila franca do campo
# Processing Record 1 of Set 10 | iwanai
# Processing Record 2 of Set 10 | grindavik
# Processing Record 3 of Set 10 | pisco
# Processing Record 4 of Set 10 | dingle
# Processing Record 5 of Set 10 | shu
# Processing Record 6 of Set 10 | dudinka
# Processing Record 7 of Set 10 | kefamenanu
# Processing Record 8 of Set 10 | havre-saint-pierre
# Processing Record 9 of Set 10 | agadez
# Processing Record 10 of Set 10 | zhigansk
# Processing Record 11 of Set 10 | olymskiy
# City not found. Skipping...
# Processing Record 12 of Set 10 | jacareacanga
# Processing Record 13 of Set 10 | jacqueville
# Processing Record 14 of Set 10 | egvekinot
# Processing Record 15 of Set 10 | labytnangi
# Processing Record 16 of Set 10 | dolzhanskaya
# Processing Record 17 of Set 10 | itoman
# Processing Record 18 of Set 10 | tres arroyos
# Processing Record 19 of Set 10 | beauly
# Processing Record 20 of Set 10 | englewood
# Processing Record 21 of Set 10 | vanimo
# Processing Record 22 of Set 10 | samfya
# Processing Record 23 of Set 10 | sassandra
# Processing Record 24 of Set 10 | matagami
# Processing Record 25 of Set 10 | taltal
# Processing Record 26 of Set 10 | lakatoro
# Processing Record 27 of Set 10 | berlevag
# Processing Record 28 of Set 10 | raga
# Processing Record 29 of Set 10 | hailey
# Processing Record 30 of Set 10 | skagen
# Processing Record 31 of Set 10 | papara
# Processing Record 32 of Set 10 | santa rosa
# Processing Record 33 of Set 10 | naryan-mar
# Processing Record 34 of Set 10 | krasnoselkup
# Processing Record 35 of Set 10 | almeirim
# Processing Record 36 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 10 | bagdarin
# Processing Record 38 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 39 of Set 10 | la concordia
# Processing Record 40 of Set 10 | manokwari
# Processing Record 41 of Set 10 | poum
# Processing Record 42 of Set 10 | mayskiy
# Processing Record 43 of Set 10 | kaeo
# Processing Record 44 of Set 10 | north bend
# Processing Record 45 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 10 | varkaus
# Processing Record 47 of Set 10 | mutoko
# Processing Record 48 of Set 10 | gizo
# Processing Record 49 of Set 10 | saurimo
# Processing Record 50 of Set 10 | cidreira
# Processing Record 1 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 11 | purpe
# Processing Record 3 of Set 11 | masloc
# Processing Record 4 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 5 of Set 11 | morgantown
# Processing Record 6 of Set 11 | amarillo
# Processing Record 7 of Set 11 | birjand
# Processing Record 8 of Set 11 | erenhot
# Processing Record 9 of Set 11 | xichang
# Processing Record 10 of Set 11 | kudahuvadhoo
# Processing Record 11 of Set 11 | aykhal
# Processing Record 12 of Set 11 | sooke
# Processing Record 13 of Set 11 | birin
# Processing Record 14 of Set 11 | isabela
# Processing Record 15 of Set 11 | yar-sale
# Processing Record 16 of Set 11 | aasiaat
# Processing Record 17 of Set 11 | toamasina
# Processing Record 18 of Set 11 | baruun-urt
# Processing Record 19 of Set 11 | rapid city
# Processing Record 20 of Set 11 | mgandu
# Processing Record 21 of Set 11 | bambanglipuro
# Processing Record 22 of Set 11 | horsham
# Processing Record 23 of Set 11 | coquimbo
# Processing Record 24 of Set 11 | topolobampo
# Processing Record 25 of Set 11 | cortez
# Processing Record 26 of Set 11 | bodden town
# Processing Record 27 of Set 11 | didsbury
# Processing Record 28 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 29 of Set 11 | vienne
# Processing Record 30 of Set 11 | lesosibirsk
# Processing Record 31 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 11 | black river
# Processing Record 33 of Set 11 | thunder bay
# Processing Record 34 of Set 11 | dalby
# Processing Record 35 of Set 11 | leshukonskoye
# Processing Record 36 of Set 11 | srednekolymsk
# Processing Record 37 of Set 11 | paamiut
# Processing Record 38 of Set 11 | lakes entrance
# Processing Record 39 of Set 11 | yellandu
# Processing Record 40 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 41 of Set 11 | ahuimanu
# Processing Record 42 of Set 11 | kenai
# Processing Record 43 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 44 of Set 11 | malindi
# Processing Record 45 of Set 11 | garowe
# Processing Record 46 of Set 11 | derna
# Processing Record 47 of Set 11 | ardahan
# Processing Record 48 of Set 11 | san vicente
# Processing Record 49 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 11 | wakkanai
# Processing Record 1 of Set 12 | ayan
# Processing Record 2 of Set 12 | kungurtug
# Processing Record 3 of Set 12 | bethanien
# Processing Record 4 of Set 12 | ulaangom
# Processing Record 5 of Set 12 | olds
# Processing Record 6 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 12 | cloquet
# Processing Record 8 of Set 12 | cangas
# Processing Record 9 of Set 12 | presidente olegario
# Processing Record 10 of Set 12 | alugan
# Processing Record 11 of Set 12 | tandil
# Processing Record 12 of Set 12 | guadalupe y calvo
# Processing Record 13 of Set 12 | olafsvik
# Processing Record 14 of Set 12 | vaitape
# Processing Record 15 of Set 12 | afyonkarahisar
# Processing Record 16 of Set 12 | montevideo
# Processing Record 17 of Set 12 | lichinga
# Processing Record 18 of Set 12 | koumac
# Processing Record 19 of Set 12 | labuhan
# Processing Record 20 of Set 12 | saint-georges
# Processing Record 21 of Set 12 | bonthe
# Processing Record 22 of Set 12 | tabou
# Processing Record 23 of Set 12 | berezovyy
# Processing Record 24 of Set 12 | rocha
# Processing Record 25 of Set 12 | ypsonas
# Processing Record 26 of Set 12 | port hedland
# Processing Record 27 of Set 12 | navahrudak
# Processing Record 28 of Set 12 | alta floresta
# Processing Record 29 of Set 12 | ara
# Processing Record 30 of Set 12 | mantua
# Processing Record 31 of Set 12 | zyryanka
# Processing Record 32 of Set 12 | assiniboia
# Processing Record 33 of Set 12 | tena
# Processing Record 34 of Set 12 | vestmannaeyjar
# Processing Record 35 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 36 of Set 12 | tazovskiy
# Processing Record 37 of Set 12 | huazolotitlan
# City not found. Skipping...
# Processing Record 38 of Set 12 | mokhsogollokh
# Processing Record 39 of Set 12 | trairi
# Processing Record 40 of Set 12 | san bartolo
# Processing Record 41 of Set 12 | pangnirtung
# Processing Record 42 of Set 12 | broken hill
# Processing Record 43 of Set 12 | ardabil
# Processing Record 44 of Set 12 | calatayud
# Processing Record 45 of Set 12 | mandiana
# Processing Record 46 of Set 12 | alekseyevka
# Processing Record 47 of Set 12 | nanakuli
# Processing Record 48 of Set 12 | toora-khem
# Processing Record 49 of Set 12 | zemio
# Processing Record 50 of Set 12 | jiaojiang
# Processing Record 1 of Set 13 | borujerd
# Processing Record 2 of Set 13 | avera
# Processing Record 3 of Set 13 | knysna
# Processing Record 4 of Set 13 | san mateo ixtatan
# Processing Record 5 of Set 13 | qovlar
# Processing Record 6 of Set 13 | yaan
# Processing Record 7 of Set 13 | dondo
# Processing Record 8 of Set 13 | mahibadhoo
# Processing Record 9 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 13 | miri
# Processing Record 11 of Set 13 | disna
# Processing Record 12 of Set 13 | liverpool
# Processing Record 13 of Set 13 | prince rupert
# Processing Record 14 of Set 13 | brigantine
# Processing Record 15 of Set 13 | beisfjord
# Processing Record 16 of Set 13 | tobol
# Processing Record 17 of Set 13 | kutum
# Processing Record 18 of Set 13 | tlaxiaca
# City not found. Skipping...
# Processing Record 19 of Set 13 | ystad
# Processing Record 20 of Set 13 | rawson
# Processing Record 21 of Set 13 | barcelona
# Processing Record 22 of Set 13 | teeswater
# Processing Record 23 of Set 13 | shihezi
# Processing Record 24 of Set 13 | ucluelet
# Processing Record 25 of Set 13 | mangochi
# Processing Record 26 of Set 13 | tostamaa
# City not found. Skipping...
# Processing Record 27 of Set 13 | lazaro cardenas
# Processing Record 28 of Set 13 | karema
# Processing Record 29 of Set 13 | eral
# Processing Record 30 of Set 13 | chabahar
# Processing Record 31 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 32 of Set 13 | nagato
# Processing Record 33 of Set 13 | nhlangano
# Processing Record 34 of Set 13 | matay
# Processing Record 35 of Set 13 | tual
# Processing Record 36 of Set 13 | goure
# Processing Record 37 of Set 13 | yeppoon
# Processing Record 38 of Set 13 | jalu
# Processing Record 39 of Set 13 | shelburne
# Processing Record 40 of Set 13 | sabha
# Processing Record 41 of Set 13 | markdorf
# Processing Record 42 of Set 13 | dar es salaam
# Processing Record 43 of Set 13 | ustye
# Processing Record 44 of Set 13 | havelock
# Processing Record 45 of Set 13 | brae
# Processing Record 46 of Set 13 | balkhash
# Processing Record 47 of Set 13 | yeghegnavan
# Processing Record 48 of Set 13 | binzhou
# Processing Record 49 of Set 13 | gornopravdinsk
# Processing Record 50 of Set 13 | bargur
# Processing Record 1 of Set 14 | cremona
# Processing Record 2 of Set 14 | portoferraio
# Processing Record 3 of Set 14 | dunmore town
# Processing Record 4 of Set 14 | aldama
# Processing Record 5 of Set 14 | asosa
# Processing Record 6 of Set 14 | miles city
# Processing Record 7 of Set 14 | youkounkoun
# Processing Record 8 of Set 14 | piranhas
# Processing Record 9 of Set 14 | isla mujeres
# Processing Record 10 of Set 14 | konevo
# Processing Record 11 of Set 14 | luena
# Processing Record 12 of Set 14 | taoudenni
# Processing Record 13 of Set 14 | kyzyl-suu
# Processing Record 14 of Set 14 | luau
# Processing Record 15 of Set 14 | banda aceh
# Processing Record 16 of Set 14 | jiutai
# Processing Record 17 of Set 14 | sumenep
# Processing Record 18 of Set 14 | kon tum
# Processing Record 19 of Set 14 | cap malheureux
# Processing Record 20 of Set 14 | scharnstein
# Processing Record 21 of Set 14 | udachnyy
# Processing Record 22 of Set 14 | sabang
# Processing Record 23 of Set 14 | magdagachi
# Processing Record 24 of Set 14 | robertsport
# Processing Record 25 of Set 14 | kantunilkin
# Processing Record 26 of Set 14 | ziro
# Processing Record 27 of Set 14 | tamiahua
# Processing Record 28 of Set 14 | grootfontein
# Processing Record 29 of Set 14 | puerto leguizamo
# Processing Record 30 of Set 14 | uong bi
# Processing Record 31 of Set 14 | la ronge
# Processing Record 32 of Set 14 | kalanwali
# Processing Record 33 of Set 14 | hanmer springs
# Processing Record 34 of Set 14 | henties bay
# Processing Record 35 of Set 14 | verkhnevilyuysk
# Processing Record 36 of Set 14 | beni mazar
# Processing Record 37 of Set 14 | tarko-sale
# Processing Record 38 of Set 14 | tiarei
# Processing Record 39 of Set 14 | kaputa
# Processing Record 40 of Set 14 | lavrentiya
# Processing Record 41 of Set 14 | calderitas
# Processing Record 42 of Set 14 | mitsamiouli
# Processing Record 43 of Set 14 | smithers
# Processing Record 44 of Set 14 | kovur
# Processing Record 45 of Set 14 | auki
# Processing Record 46 of Set 14 | san carlos de bariloche
# Processing Record 47 of Set 14 | odweyne
# Processing Record 48 of Set 14 | vila do maio
# Processing Record 49 of Set 14 | ugoofaaru
# Processing Record 50 of Set 14 | eston
# Processing Record 1 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 15 | navirai
# Processing Record 3 of Set 15 | karanganyar
# Processing Record 4 of Set 15 | catumbela
# Processing Record 5 of Set 15 | kantang
# Processing Record 6 of Set 15 | ushtobe
# Processing Record 7 of Set 15 | sioux lookout
# Processing Record 8 of Set 15 | maniitsoq
# Processing Record 9 of Set 15 | omsukchan
# Processing Record 10 of Set 15 | mangit
# Processing Record 11 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 15 | kolomna
# Processing Record 13 of Set 15 | lesnoy
# Processing Record 14 of Set 15 | chichawatni
# Processing Record 15 of Set 15 | deblin
# Processing Record 16 of Set 15 | simbakoro
# Processing Record 17 of Set 15 | zaysan
# Processing Record 18 of Set 15 | yekaterinoslavka
# Processing Record 19 of Set 15 | loukhi
# Processing Record 20 of Set 15 | nargana
# Processing Record 21 of Set 15 | tymovskoye
# Processing Record 22 of Set 15 | porto novo
# Processing Record 23 of Set 15 | preston
# Processing Record 24 of Set 15 | arenapolis
# Processing Record 25 of Set 15 | derzhavinsk
# Processing Record 26 of Set 15 | ratnagiri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 665

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Mataura      NZ -46.1927  168.8643     66.61        60         100
# 1     Pombas      CV  17.1503  -25.0201     69.58        69          11
# 2      Bluff      NZ -46.6000  168.3333     62.94        76         100
# 3        Sur      OM  22.5667   59.5289     79.57        51           0
# 4  Jamestown      US  42.0970  -79.2353     42.44        50         100
# 5  Busselton      AU -33.6500  115.3333     61.12        60           0
# 6  Tuatapere      NZ -46.1333  167.6833     66.69        69         100
# 7    Rikitea      PF -23.1203 -134.9692     78.24        64          69
# 8      Roald      NO  62.5833    6.1333     32.32        93          75
# 9     Maceio      BR  -9.6658  -35.7353     76.44        88          20
#
#    Wind Speed Current Description
# 0        2.75          light rain
# 1       10.31          few clouds
# 2        8.08     overcast clouds
# 3       12.62           clear sky
# 4        5.75     overcast clouds
# 5        9.82           clear sky
# 6        5.77          light rain
# 7       11.56       broken clouds
# 8        4.61                snow
# 9        2.30          few clouds

# %%
city_data_df=city_data_df[['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']]
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Mataura      NZ -46.1927  168.8643     66.61        60         100
# 1     Pombas      CV  17.1503  -25.0201     69.58        69          11
# 2      Bluff      NZ -46.6000  168.3333     62.94        76         100
# 3        Sur      OM  22.5667   59.5289     79.57        51           0
# 4  Jamestown      US  42.0970  -79.2353     42.44        50         100
# 5  Busselton      AU -33.6500  115.3333     61.12        60           0
# 6  Tuatapere      NZ -46.1333  167.6833     66.69        69         100
# 7    Rikitea      PF -23.1203 -134.9692     78.24        64          69
# 8      Roald      NO  62.5833    6.1333     32.32        93          75
# 9     Maceio      BR  -9.6658  -35.7353     76.44        88          20
#
#    Wind Speed Current Description
# 0        2.75          light rain
# 1       10.31          few clouds
# 2        8.08     overcast clouds
# 3       12.62           clear sky
# 4        5.75     overcast clouds
# 5        9.82           clear sky
# 6        5.77          light rain
# 7       11.56       broken clouds
# 8        4.61                snow
# 9        2.30          few clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
